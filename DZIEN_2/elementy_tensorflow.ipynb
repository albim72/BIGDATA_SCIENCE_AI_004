# %%
import tensorflow as tf

# %%
print(f'wersja tf: {tf.__version__}')
# Out:
# wersja tf: 2.13.1

# %%
# !pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in /opt/python/envs/default/lib/python3.8/site-packages (24.3.1)
# Collecting pip
#   Downloading pip-25.0-py3-none-any.whl.metadata (3.7 kB)
# Downloading pip-25.0-py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 30.1 MB/s eta 0:00:00
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 24.3.1
#     Uninstalling pip-24.3.1:
#       Successfully uninstalled pip-24.3.1
# Successfully installed pip-25.0

# %%
# !python --version
# Out:
# Python 3.8.20

# %%
# !sudo apt update && sudo apt install python3.11

# %%
#implementacja zbioru danych MNIST
mnist = tf.keras.datasets.mnist

# %%
(x_train,y_train),(x_test,y_test) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 1s 0us/step

# %%
#normalizacja danych - obrazów
x_train, x_test = x_train/255.0, x_test/255.0

# %%
x_train.shape
# Out:
# (60000, 28, 28)

# %%
x_test.shape
# Out:
# (10000, 28, 28)

# %%
#pierwszy model sieci neuronowej tf
model = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(input_shape=(28,28)),
    tf.keras.layers.Dense(128,activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(10)
])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 128)               100480
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 101770 (397.54 KB)
# Trainable params: 101770 (397.54 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
#deklaracja propagacji wstecznej - kompilacja modelu
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
history = model.fit(x_train,y_train,epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 9s 4ms/step - loss: 0.2975 - accuracy: 0.9140
# Epoch 2/10
# 1875/1875 [==============================] - 12s 7ms/step - loss: 0.1437 - accuracy: 0.9567
# Epoch 3/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.1066 - accuracy: 0.9673
# Epoch 4/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0872 - accuracy: 0.9731
# Epoch 5/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0746 - accuracy: 0.9772
# Epoch 6/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0663 - accuracy: 0.9787
# Epoch 7/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0600 - accuracy: 0.9813
# Epoch 8/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0533 - accuracy: 0.9822
# Epoch 9/10
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0496 - accuracy: 0.9837
# Epoch 10/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0446 - accuracy: 0.9850

# %%
#ocena modelu
test_loss, test_accuracy = model.evaluate(x_test,y_test,verbose=2)
print(f"strata {test_loss}")
print(f"accuracy: {test_accuracy}")
# Out:
# 313/313 - 1s - loss: 0.0780 - accuracy: 0.9769 - 596ms/epoch - 2ms/step
# strata 0.0779864490032196
# accuracy: 0.9768999814987183
